# %%
! pip install pyodbc
! pip install mssql
# Out:
# Requirement already satisfied: pyodbc in /opt/anaconda3/envs/glueviz/lib/python3.11/site-packages (5.3.0)
# Collecting mssql
#   Downloading mssql-1.0.1-py3-none-any.whl.metadata (664 bytes)
# Requirement already satisfied: sqlalchemy in /opt/anaconda3/envs/glueviz/lib/python3.11/site-packages (from mssql) (2.0.44)
# Requirement already satisfied: pyodbc in /opt/anaconda3/envs/glueviz/lib/python3.11/site-packages (from mssql) (5.3.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/envs/glueviz/lib/python3.11/site-packages (from sqlalchemy->mssql) (4.11.0)
# Downloading mssql-1.0.1-py3-none-any.whl (3.7 kB)
# Installing collected packages: mssql
# Successfully installed mssql-1.0.1

# %%
import pyodbc
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import os

# %%
password = os.getenv("PASSWORD")

con_str = (
    "Driver={ODBC Driver 18 for SQL Server};"
    "Server=tcp:pankaj.database.windows.net,1433;"
    "Database=Sales;"
    "Uid=pankaj;"
    f"Pwd={password};"
    "Encrypt=yes;"
    "TrustServerCertificate=no;"
    "Connection Timeout=30;"
)

conn = pyodbc.connect(con_str)
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[19], line 14
#       1 password = os.getenv("PASSWORD")
#       3 con_str = (
#       4     "Driver={ODBC Driver 18 for SQL Server};"
#       5     "Server=tcp:pankaj.database.windows.net,1433;"
#    (...)
#      11     "Connection Timeout=30;"
#      12 )
# ---> 14 conn = pyodbc.connect(con_str)
#
# InterfaceError: ('28000', "[28000] [Microsoft][ODBC Driver 18 for SQL Server][SQL Server]Login failed for user 'pankaj'. (18456) (SQLDriverConnect)")

# %%
con_str = (
    "Driver={ODBC Driver 18 for SQL Server};"
    "Server=tcp:pankaj.database.windows.net,1433;"
    "Database=Sales;"
    "Uid=pankaj;"
    f"Pwd={os.getenv("PASSWORD")};"
    "Encrypt=yes;"
    "TrustServerCertificate=no;"
    "Connection Timeout=30;"
)

conn = pyodbc.connect(con_str)
# Out:
#   Cell In[15], line 6
#     f"Pwd={os.getenv("PASSWORD")};"
#                       ^
# SyntaxError: f-string: unmatched '('
